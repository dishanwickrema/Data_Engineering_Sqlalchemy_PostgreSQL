# %%
import pandas as pd

# %%
Branch_General_Profile = pd.read_csv("resources/Branch_General_Profile.csv")
Active_Cardholders = pd.read_csv("resources/Active_Cardholders.csv")
Active_Cardholders_by_Cardholder_Type = pd.read_csv("resources/Active_Cardholders_by_Cardholder_Type.csv")
Annual_Visits = pd.read_csv("resources/Annual_Visits.csv")
Catchment_Population = pd.read_csv("resources/Catchment_Population.csv")
Collection_Size = pd.read_csv("resources/Collection_Size.csv")
Hours_of_Operation = pd.read_csv("resources/Hours_of_Operation.csv")
New_Registrations = pd.read_csv("resources/New_Registrations.csv")
Registered_Cardholders = pd.read_csv("resources/Registered_Cardholders.csv")
Registered_Cardholders_by_Cardholder_Type = pd.read_csv("resources/Registered_Cardholders_by_Cardholder_Type.csv")
Circulation_by_Cardholder_Type = pd.read_csv("resources/Circulation_by_Cardholder_Type.csv")
Workstations = pd.read_csv("resources/Workstations.csv")
Workstation_Users = pd.read_csv("resources/Workstation_Users.csv")

# %%
Branch_General_Profile.head()
Active_Cardholders_by_Cardholder_Type.head()
# Out:
#     ID       Branch Name Tier              Address      Telephone   \
# 0   AG        Agincourt   DL         155 Bonis Ave  (416) 396-8943
# 1  ACD  Albert Campbell    DL    496 Birchmount Rd  (416) 396-8890
# 2   AB            Albion   DL       1515 Albion Rd  (416) 394-5170
# 3   AD         Alderwood   NL         2 Orianna Dr  (416) 394-5310
# 4   AP     Amesbury Park   NL  1565 Lawrence Ave W  (416) 395-5420
#
#   Postal Code  FSA NBHD Number                          NBHD Name  \
# 0     M1T 3W6  M1T         118            Tam O'Shanter-Sullivan
# 1     M1K 1N8  M1K         120               Clairlea-Birchmount
# 2     M9V 1B2  M9V           2  Mount Olive-Silverstone-Jamestown
# 3     M8W 4Y1  M8W          20                          Alderwood
# 4     M6L 1A8  M6L          30               Brookhaven-Amesbury
#
#    Ward Number             Ward Region
# 0           40  Scarborough-Agincourt
# 1           35   Scarborough-Southwest
# 2            1         Etobicoke North
# 3            6     Etobicoke Lakeshore
# 4           12       York South-Weston

# %%
Active_Cardholders.head()
# Out:
#     ID      Branch Name Tier     2017     2016     2015     2014     2013  \
# 0   AG        Agincourt   DL  13893.0  14975.0  16654.0  16112.0  19423.0
# 1  ACD  Albert Campbell   DL   7859.0   8075.0   8539.0   8180.0   9746.0
# 2   AB           Albion   DL  17440.0  15363.0  16132.0  14363.0  19204.0
# 3   AD        Alderwood   NL   3179.0   3116.0   3120.0   2944.0   3296.0
# 4   AP    Amesbury Park   NL   2956.0   3544.0   3770.0   3660.0   4183.0
#
#       2012     2011     2010
# 0  19660.0  19155.0  24961.0
# 1   9788.0   9377.0  12391.0
# 2  20109.0  18789.0  24597.0
# 3   3262.0   3164.0   4018.0
# 4   4319.0   4001.0   5074.0
